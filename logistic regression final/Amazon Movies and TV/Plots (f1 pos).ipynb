# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a = DataFrame([['100K', 0.938, 0.940],
                 ['200K', 0.939, 0.940],
                 ['500K', 0.939, 0.942],
                 ['1000K', 0.940, 0.943],
                 ['all', 0.941, 0.943]], columns = ['n_rows', 'acc', 'f1'])

# %%
b = DataFrame([['100K', 0.617, 0.560],
                 ['200K', 0.649, 0.610],
                 ['500K', 0.650, 0.610],
                 ['1000K', 0.667, 0.641],
                 ['all', 0.675, 0.651]], columns = ['n_rows', 'acc', 'f1'])

# %%
plt.figure(figsize=((12,6)))
xs = [i for i, _ in enumerate(a.acc)]
plt.plot(xs, a.acc, 'g-', label='Accuracy')
plt.plot(xs, a.f1, 'r-', label='F1 score_neg')
# plt.axis([0, 4, 0, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, a.n_rows)
plt.title("Amazon data")
plt.ylim([0.935, 0.945])
plt.legend()
plt.show()

# %%
plt.figure(figsize=((12,6)))
xs = [i for i, _ in enumerate(b.acc)]
plt.plot(xs, b.acc, 'g-', label='Accuracy')
plt.plot(xs, b.f1, 'r-', label='F1 score_neg')
# plt.axis([0, 4, .9, 1.])
plt.xlabel("number of train samples")
plt.xticks(xs, b.n_rows)
plt.title("Test data")
plt.legend()
plt.show()
